# %%
#1. Deletion

#Listwise Deletion: Remove rows with any missing values.

data_cleaned = data.dropna()
 
#2. Imputation

#Mean Imputation: Replace missing values with the column mean (numerical data)

data['ColumnName'].fillna(data['ColumnName'].mean(), inplace=True)
 
# Median Imputation: Use the column median

data['ColumnName'].fillna(data['ColumnName'].median(), inplace=True)
 
#Mode Imputation: Use the most frequent value (categorical data)

data['ColumnName'].fillna(data['ColumnName'].mode()[0], inplace=True)
 
# Check for duplicate rows

duplicates = data.duplicated()

print(f"Number of duplicate rows: {duplicates.sum()}")
 
# Display duplicated rows

print(data[data.duplicated()])
 
#Remove all duplicate rows (full duplicates):

data_cleaned = data.drop_duplicates()
 
#Remove duplicates based on specific columns (partial duplicates):

data_cleaned = data.drop_duplicates(subset=['Name', 'Age'])
 
#Keeping the First/Last Occurrence

#You can choose to keep either the first or last occurrence of a duplicate row.
 
# Keep the first occurrence of each duplicate

data_cleaned = data.drop_duplicates(keep='first')
 
# Keep the last occurrence

data_cleaned = data.drop_duplicates(keep='last')

 
# Replace typos in 'City' column

data['City'] = data['City'].replace({'Nwe York': 'New York', 'Los Angles': 'Los Angeles'})

 
# Convert all text in 'City' column to lowercase

data['City'] = data['City'].str.lower()

 
Remove extra spaces:

data['City'] = data['City'].str.strip()

 
Handle inconsistent delimiters in categorical data:

data['Education'] = data['Education'].str.replace(';', ',')

# %%
import pandas as pd
data=pd.read_csv('Automobile.csv')
data
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
data.dtypes
# Out:
# symboling                int64
# normalized_losses        int64
# make                    object
# fuel_type               object
# aspiration              object
# number_of_doors         object
# body_style              object
# drive_wheels            object
# engine_location         object
# wheel_base             float64
# length                 float64
# width                  float64
# height                 float64
# curb_weight              int64
# engine_type             object
# number_of_cylinders     object
# engine_size              int64
# fuel_system             object
# bore                   float64
# stroke                 float64
# compression_ratio      float64
# horsepower               int64
# peak_rpm                 int64
# city_mpg                 int64
# highway_mpg              int64
# price                    int64
# dtype: object

# %%
#fill missing values by mean
data['horsepower'].fillna(data['horsepower'].mean(),inplace=True)
print(data['horsepower'].mean())
# Out:
# 103.2636815920398

# %%
#fill missing values by median
data['price'].fillna(data['price'].median(),inplace=True)
print(data['price'].median())
# Out:
# 10295.0

# %%
#converting object datatype into category
data['fuel_type']=data['fuel_type'].astype('category')
data['aspiration']=data['aspiration'].astype('category')
data.dtypes
# Out:
# symboling                 int64
# normalized_losses         int64
# make                     object
# fuel_type              category
# aspiration             category
# number_of_doors          object
# body_style               object
# drive_wheels             object
# engine_location          object
# wheel_base              float64
# length                  float64
# width                   float64
# height                  float64
# curb_weight               int64
# engine_type              object
# number_of_cylinders      object
# engine_size               int64
# fuel_system              object
# bore                    float64
# stroke                  float64
# compression_ratio       float64
# horsepower                int64
# peak_rpm                  int64
# city_mpg                  int64
# highway_mpg               int64
# price                     int64
# dtype: object

# %%
print(data[['aspiration','fuel_type']])
# Out:
#     aspiration fuel_type
# 0          std       gas
# 1          std       gas
# 2          std       gas
# 3          std       gas
# 4          std       gas
# ..         ...       ...
# 196        std       gas
# 197      turbo       gas
# 198        std       gas
# 199      turbo    diesel
# 200      turbo       gas
#
# [201 rows x 2 columns]

# %%
#conert aspiration,fuel_type to lowercase
data['aspiration']=data['aspiration'].str.lower()
data['fuel_type']=data['fuel_type'].str.lower()

# %%
#replace the special characters with ''
data['aspiration']=data['aspiration'].str.replace(r'[^A-Za-z0-9_]', '', regex=True)
data['fuel_type']=data['fuel_type'].str.replace(r'[^A-Za-z0-9_]', '', regex=True)

# %%
#convert string to integer
data['number_of_cylinders']=data['number_of_cylinders'].replace({"four":"4","six":"6","eight":"8"})

# %%
#Standardize fuel_system categories
data['fuel_system']=data['fuel_system'].replace({"mpfi":"Multi-Point Fuel Injection","spdi":"Single-Point Fuel Injection"})

# %%
data['horsepower']
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 196    114
# 197    160
# 198    134
# 199    106
# 200    114
# Name: horsepower, Length: 201, dtype: int64

# %%
#convert int to numeric anf fill the missing values 
data['price']=pd.to_numeric(data['price'],errors='coerce')
data['price'].fillna(data['price'].mean())
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 196    16845
# 197    19045
# 198    21485
# 199    22470
# 200    22625
# Name: price, Length: 201, dtype: int64

# %%
data.dtypes
# Out:
# symboling                int64
# normalized_losses        int64
# make                    object
# fuel_type               object
# aspiration              object
# number_of_doors         object
# body_style              object
# drive_wheels            object
# engine_location         object
# wheel_base             float64
# length                 float64
# width                  float64
# height                 float64
# curb_weight              int64
# engine_type             object
# number_of_cylinders     object
# engine_size              int64
# fuel_system             object
# bore                   float64
# stroke                 float64
# compression_ratio      float64
# horsepower               int64
# peak_rpm                 int64
# city_mpg                 int64
# highway_mpg              int64
# price                    int64
# dtype: object

# %%
#convert horse power to kw
data["kw"]=data['horsepower']*0.7457
data
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
#adding new features Power-to-weight ratio
data['Power-to-weight ratio']=data['horsepower']/data['curb_weight']
data
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
#adding engine efficiency
data['Engine efficiency']=data['horsepower']/data['engine_size']

# %%
#adding fuel efficiency
data['Fuel efficiency']=data['city_mpg']/data['highway_mpg']

# %%
data['compression_ratio']=data['compression_ratio'].astype('category')
data.dtypes
# Out:
# symboling                   int64
# normalized_losses           int64
# make                       object
# fuel_type                  object
# aspiration                 object
# number_of_doors            object
# body_style                 object
# drive_wheels               object
# engine_location            object
# wheel_base                float64
# length                    float64
# width                     float64
# height                    float64
# curb_weight                 int64
# engine_type                object
# number_of_cylinders        object
# engine_size                 int64
# fuel_system                object
# bore                      float64
# stroke                    float64
# compression_ratio        category
# horsepower                  int64
# peak_rpm                    int64
# city_mpg                    int64
# highway_mpg                 int64
# price                       int64
# kw                        float64
# ...

# %%
data['compression_ratio'] = pd.to_numeric(data['compression_ratio'], errors='coerce')

# %%
#grouping the columns low<9 and medium 9-11 and high >11
data['compression_category'] = np.where(data['compression_ratio'] < 9, "Low",
                                       np.where((data['compression_ratio'] >= 9) & (data['compression_ratio'] < 11), "Medium", "High"))

# %%
#converting to category
data['compression_category'] = data['compression_category'].astype('category')

# %%
data['normalized_losses']
# Out:
# 0      168
# 1      168
# 2      168
# 3      164
# 4      164
#       ...
# 196     95
# 197     95
# 198     95
# 199     95
# 200     95
# Name: normalized_losses, Length: 201, dtype: int64

# %%
bins=[0,200,500,float('inf')]
labels=['Low','Medium','High']
data['loss_category'] = pd.cut(data['normalized_losses'], bins=bins, labels=labels, right=False)
data
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
numerical_columns = ['length', 'width', 'height', 'curb_weight', 'engine_size']
min_max_scaler = MinMaxScaler()
data_min_max_scaled = data.copy() 
data_min_max_scaled[numerical_columns] = min_max_scaler.fit_transform(data[numerical_columns])
print("Min-Max Scaled Data:")
print(data_min_max_scaled)
standard_scaler = StandardScaler()
data_standard_scaled = data.copy()  
data_standard_scaled[numerical_columns] = standard_scaler.fit_transform(data[numerical_columns])
print("\nStandardized Data:")
print(data_standard_scaled)
# Out:
# Min-Max Scaled Data:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# ...

# %%
#label encoding 
import pandas as pd
from sklearn.preprocessing import LabelEncoder
label_cols = ["fuel_type", "aspiration", "drive_wheels"]
label_encoders = {}
for col in label_cols:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    label_encoders[col] = le 
one_hot_cols = ["body_style", "engine_type", "fuel_system"]
data = pd.get_dummies(data, columns=one_hot_cols)
print(data)
# Out:
#      symboling  normalized_losses         make  fuel_type  aspiration  \
# 0            3                168  alfa-romero          1           0
# 1            3                168  alfa-romero          1           0
# 2            1                168  alfa-romero          1           0
# 3            2                164         audi          1           0
# 4            2                164         audi          1           0
# ..         ...                ...          ...        ...         ...
# 196         -1                 95        volvo          1           0
# 197         -1                 95        volvo          1           1
# 198         -1                 95        volvo          1           0
# 199         -1                 95        volvo          0           1
# 200         -1                 95        volvo          1           1
#
#     number_of_doors  drive_wheels engine_location  wheel_base  length  ...  \
# ...
